# %%
# import packages
from nba_api.stats.endpoints import shotchartdetail
import pandas as pd
import json
import requests
import datetime

# %%
# create first JSON request
shot_json1 = shotchartdetail.ShotChartDetail(
            team_id= 0, # can input the id but 0, will return all
            player_id= 0, # can input the id but 0, will return all
            context_measure_simple= 'FGA', #also 'PTS' has only makes
            season_nullable= '2023-24',
            season_type_all_star= 'Regular Season') # can include many season

# %%
# Load data into a Python dictionary
shot_data1 = json.loads(shot_json1.get_json())

# %%
# Get the relevant data from our dictionary
relevant_data1 = shot_data1['resultSets'][0]

# Get the headers and rows data
headers = relevant_data1['headers']
rows = relevant_data1['rowSet']

# Create pandas DataFrame

nba_shoot_data1 = pd.DataFrame(rows)
nba_shoot_data1.columns = headers

# %%
nba_shoot_data1
# Out:
#                 GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0       Shot Chart Detail  0022300001              7    1626167
# 1       Shot Chart Detail  0022300001              9    1630596
# 2       Shot Chart Detail  0022300001             11    1628971
# 3       Shot Chart Detail  0022300001             13    1631097
# 4       Shot Chart Detail  0022300001             15    1628378
# ...                   ...         ...            ...        ...
# 146283  Shot Chart Detail  0022301230            644    1641720
# 146284  Shot Chart Detail  0022301230            646    1641722
# 146285  Shot Chart Detail  0022301230            648    1631108
# 146286  Shot Chart Detail  0022301230            649    1641722
# 146287  Shot Chart Detail  0022301230            652    1630700
#
#                 PLAYER_NAME     TEAM_ID             TEAM_NAME  PERIOD  \
# 0              Myles Turner  1610612754        Indiana Pacers       1
# 1               Evan Mobley  1610612739   Cleveland Cavaliers       1
# 2               Bruce Brown  1610612754        Indiana Pacers       1
# 3        Bennedict Mathurin  1610612754        Indiana Pacers       1
# 4          Donovan Mitchell  1610612739   Cleveland Cavaliers       1
# ...                     ...         ...                   ...     ...
# 146283  Jalen Hood-Schifino  1610612747    Los Angeles Lakers       4
# 146284       Jordan Hawkins  1610612740  New Orleans Pelicans       4
# 146285         Max Christie  1610612747    Los Angeles Lakers       4
# 146286       Jordan Hawkins  1610612740  New Orleans Pelicans       4
# 146287        Dyson Daniels  1610612740  New Orleans Pelicans       4
#
#         MINUTES_REMAINING  SECONDS_REMAINING  ...         SHOT_ZONE_AREA  \
# 0                      11                 41  ...              Center(C)
# 1                      11                 23  ...              Center(C)
# 2                      11                 15  ...              Center(C)
# 3                      11                  9  ...  Right Side Center(RC)
# 4                      10                 56  ...              Center(C)
# ...                   ...                ...  ...                    ...
# 146283                  1                 39  ...              Center(C)
# 146284                  1                 31  ...           Left Side(L)
# 146285                  1                 13  ...              Center(C)
# 146286                  0                 59  ...              Center(C)
# 146287                  0                 24  ...  Right Side Center(RC)
#
#         SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0       Less Than 8 ft.             2     2    21                   1
# 1       Less Than 8 ft.             7    59    53                   1
# 2       Less Than 8 ft.             2    13    18                   1
# 3               24+ ft.            28   151   237                   1
# 4       Less Than 8 ft.             2   -20     1                   1
# ...                 ...           ...   ...   ...                 ...
# 146283        16-24 ft.            22    64   218                   1
# 146284        16-24 ft.            21  -206    71                   1
# 146285         8-16 ft.            11   -15   115                   1
# 146286        16-24 ft.            18   -32   179                   1
# 146287          24+ ft.            28   154   236                   1
#
#         SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                    1   20231103  IND  CLE
# 1                    0   20231103  IND  CLE
# 2                    0   20231103  IND  CLE
# 3                    1   20231103  IND  CLE
# 4                    1   20231103  IND  CLE
# ...                ...        ...  ...  ...
# 146283               0   20231207  LAL  NOP
# 146284               0   20231207  LAL  NOP
# 146285               1   20231207  LAL  NOP
# 146286               0   20231207  LAL  NOP
# 146287               0   20231207  LAL  NOP
#
# [146288 rows x 24 columns]

# %%
# Create a SECOND JSON request 
# this is for last years data
shot_json2 = shotchartdetail.ShotChartDetail(
            team_id = 0, # can input the id# but 0, will return all
            player_id = 0, # can input the id# but 0, will return all
            context_measure_simple = 'FGA', # also 'PTS' has ONLY makes
            season_nullable = '2022-23',
            season_type_all_star = 'Regular Season')    # can incldue (Pre Season, Playoffs, All Star)

# Load data into a Python dictionary
shot_data2 = json.loads(shot_json2.get_json())

# Get the relevant data from our dictionary
relevant_data2 = shot_data2['resultSets'][0]

# Get the headers and row data
headers = relevant_data2['headers']
rows = relevant_data2['rowSet']

# Create pandas DataFrame
nba_shot_data2 = pd.DataFrame(rows)
nba_shot_data2.columns = headers

# %%
nba_shot_data2
# Out:
#                 GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0       Shot Chart Detail  0022200001              7     203954
# 1       Shot Chart Detail  0022200001             11     203935
# 2       Shot Chart Detail  0022200001             12     202699
# 3       Shot Chart Detail  0022200001             14     202699
# 4       Shot Chart Detail  0022200001             15    1628369
# ...                   ...         ...            ...        ...
# 217215  Shot Chart Detail  0022201230            634    1630541
# 217216  Shot Chart Detail  0022201230            636    1631219
# 217217  Shot Chart Detail  0022201230            638    1630228
# 217218  Shot Chart Detail  0022201230            640    1631116
# 217219  Shot Chart Detail  0022201230            642    1630219
#
#                 PLAYER_NAME     TEAM_ID               TEAM_NAME  PERIOD  \
# 0               Joel Embiid  1610612755      Philadelphia 76ers       1
# 1              Marcus Smart  1610612738          Boston Celtics       1
# 2             Tobias Harris  1610612755      Philadelphia 76ers       1
# 3             Tobias Harris  1610612755      Philadelphia 76ers       1
# 4              Jayson Tatum  1610612738          Boston Celtics       1
# ...                     ...         ...                     ...     ...
# 217215          Moses Moody  1610612744   Golden State Warriors       4
# 217216      John Butler Jr.  1610612757  Portland Trail Blazers       4
# 217217     Jonathan Kuminga  1610612744   Golden State Warriors       4
# 217218  Patrick Baldwin Jr.  1610612744   Golden State Warriors       4
# 217219          Skylar Mays  1610612757  Portland Trail Blazers       4
#
#         MINUTES_REMAINING  SECONDS_REMAINING  ... SHOT_ZONE_AREA  \
# 0                      11                 38  ...   Left Side(L)
# 1                      11                 15  ...  Right Side(R)
# 2                      11                  5  ...      Center(C)
# 3                      11                  3  ...      Center(C)
# 4                      10                 46  ...   Left Side(L)
# ...                   ...                ...  ...            ...
# 217215                  1                 11  ...      Center(C)
# 217216                  1                  0  ...  Right Side(R)
# 217217                  0                 44  ...  Right Side(R)
# 217218                  0                 36  ...   Left Side(L)
# 217219                  0                 27  ...      Center(C)
#
#         SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0              8-16 ft.            12  -118    50                   1
# 1              8-16 ft.            13   120    55                   1
# 2              8-16 ft.            14    50   135                   1
# 3       Less Than 8 ft.             0     0     0                   1
# 4               24+ ft.            23  -232    49                   1
# ...                 ...           ...   ...   ...                 ...
# 217215  Less Than 8 ft.             1    11     3                   1
# 217216          24+ ft.            23   224    84                   1
# 217217        16-24 ft.            23   199   126                   1
# 217218         8-16 ft.             8   -71    52                   1
# 217219         8-16 ft.            12   -13   120                   1
#
#         SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                    0   20221018  BOS  PHI
# 1                    1   20221018  BOS  PHI
# 2                    0   20221018  BOS  PHI
# 3                    1   20221018  BOS  PHI
# 4                    1   20221018  BOS  PHI
# ...                ...        ...  ...  ...
# 217215               1   20230409  POR  GSW
# 217216               1   20230409  POR  GSW
# 217217               0   20230409  POR  GSW
# 217218               0   20230409  POR  GSW
# 217219               0   20230409  POR  GSW
#
# [217220 rows x 24 columns]

# %%
# combine both dataframes from each year
nba_shot_data = pd.concat([nba_shoot_data1, nba_shot_data2])

# %%
nba_shot_data.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0  Shot Chart Detail  0022300001              7    1626167
# 1  Shot Chart Detail  0022300001              9    1630596
# 2  Shot Chart Detail  0022300001             11    1628971
# 3  Shot Chart Detail  0022300001             13    1631097
# 4  Shot Chart Detail  0022300001             15    1628378
#
#           PLAYER_NAME     TEAM_ID            TEAM_NAME  PERIOD  \
# 0        Myles Turner  1610612754       Indiana Pacers       1
# 1         Evan Mobley  1610612739  Cleveland Cavaliers       1
# 2         Bruce Brown  1610612754       Indiana Pacers       1
# 3  Bennedict Mathurin  1610612754       Indiana Pacers       1
# 4    Donovan Mitchell  1610612739  Cleveland Cavaliers       1
#
#    MINUTES_REMAINING  SECONDS_REMAINING  ...         SHOT_ZONE_AREA  \
# 0                 11                 41  ...              Center(C)
# 1                 11                 23  ...              Center(C)
# 2                 11                 15  ...              Center(C)
# 3                 11                  9  ...  Right Side Center(RC)
# 4                 10                 56  ...              Center(C)
#
#    SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0  Less Than 8 ft.             2     2    21                   1
# 1  Less Than 8 ft.             7    59    53                   1
# 2  Less Than 8 ft.             2    13    18                   1
# 3          24+ ft.            28   151   237                   1
# 4  Less Than 8 ft.             2   -20     1                   1
#
#    SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0               1   20231103  IND  CLE
# 1               0   20231103  IND  CLE
# 2               0   20231103  IND  CLE
# 3               1   20231103  IND  CLE
# 4               1   20231103  IND  CLE
#
# [5 rows x 24 columns]

# %%
# update game data type
nba_shot_data['GAME_DATE'] = nba_shot_data['GAME_DATE'].apply(lambda x: datetime.datetime.strptime(x, '%Y%m%d').strftime('%m-%d-%Y'))

# %%
# update SHOT_TYPE column 
# Replace "2PT Field Goal" with "2PT FG"
nba_shot_data['SHOT_TYPE'] = nba_shot_data['SHOT_TYPE'].replace('2PT Field Goal', '2PT FG')
nba_shot_data['SHOT_TYPE'] = nba_shot_data['SHOT_TYPE'].replace('3PT Field Goal', '3PT FG')

nba_shot_data.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0  Shot Chart Detail  0022300001              7    1626167
# 1  Shot Chart Detail  0022300001              9    1630596
# 2  Shot Chart Detail  0022300001             11    1628971
# 3  Shot Chart Detail  0022300001             13    1631097
# 4  Shot Chart Detail  0022300001             15    1628378
#
#           PLAYER_NAME     TEAM_ID            TEAM_NAME  PERIOD  \
# 0        Myles Turner  1610612754       Indiana Pacers       1
# 1         Evan Mobley  1610612739  Cleveland Cavaliers       1
# 2         Bruce Brown  1610612754       Indiana Pacers       1
# 3  Bennedict Mathurin  1610612754       Indiana Pacers       1
# 4    Donovan Mitchell  1610612739  Cleveland Cavaliers       1
#
#    MINUTES_REMAINING  SECONDS_REMAINING  ...         SHOT_ZONE_AREA  \
# 0                 11                 41  ...              Center(C)
# 1                 11                 23  ...              Center(C)
# 2                 11                 15  ...              Center(C)
# 3                 11                  9  ...  Right Side Center(RC)
# 4                 10                 56  ...              Center(C)
#
#    SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  \
# 0  Less Than 8 ft.             2     2    21                   1
# 1  Less Than 8 ft.             7    59    53                   1
# 2  Less Than 8 ft.             2    13    18                   1
# 3          24+ ft.            28   151   237                   1
# 4  Less Than 8 ft.             2   -20     1                   1
#
#    SHOT_MADE_FLAG   GAME_DATE  HTM  VTM
# 0               1  11-03-2023  IND  CLE
# 1               0  11-03-2023  IND  CLE
# 2               0  11-03-2023  IND  CLE
# 3               1  11-03-2023  IND  CLE
# 4               1  11-03-2023  IND  CLE
#
# [5 rows x 24 columns]

# %%
# Update Period Column, by defining a function to map Period to Quarter
# define function to map period to quarter 

def map_period_to_qtr(period):
    quarter_map = { 1 : 'Q1', 2: 'Q2', 3:'Q3', 4:'Q4', 5:'OT1', 6:'OT2', 7:'OT3', 8:'OT4'}
    return quarter_map.get(period)

# Add column for quarter
nba_shot_data['QUARTER'] = nba_shot_data['PERIOD'].apply(map_period_to_qtr)

nba_shot_data.head()
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0  Shot Chart Detail  0022300001              7    1626167
# 1  Shot Chart Detail  0022300001              9    1630596
# 2  Shot Chart Detail  0022300001             11    1628971
# 3  Shot Chart Detail  0022300001             13    1631097
# 4  Shot Chart Detail  0022300001             15    1628378
#
#           PLAYER_NAME     TEAM_ID            TEAM_NAME  PERIOD  \
# 0        Myles Turner  1610612754       Indiana Pacers       1
# 1         Evan Mobley  1610612739  Cleveland Cavaliers       1
# 2         Bruce Brown  1610612754       Indiana Pacers       1
# 3  Bennedict Mathurin  1610612754       Indiana Pacers       1
# 4    Donovan Mitchell  1610612739  Cleveland Cavaliers       1
#
#    MINUTES_REMAINING  SECONDS_REMAINING  ...  SHOT_ZONE_RANGE SHOT_DISTANCE  \
# 0                 11                 41  ...  Less Than 8 ft.             2
# 1                 11                 23  ...  Less Than 8 ft.             7
# 2                 11                 15  ...  Less Than 8 ft.             2
# 3                 11                  9  ...          24+ ft.            28
# 4                 10                 56  ...  Less Than 8 ft.             2
#
#   LOC_X LOC_Y SHOT_ATTEMPTED_FLAG SHOT_MADE_FLAG   GAME_DATE  HTM  VTM  \
# 0     2    21                   1              1  11-03-2023  IND  CLE
# 1    59    53                   1              0  11-03-2023  IND  CLE
# 2    13    18                   1              0  11-03-2023  IND  CLE
# 3   151   237                   1              1  11-03-2023  IND  CLE
# 4   -20     1                   1              1  11-03-2023  IND  CLE
#
#    QUARTER
# 0       Q1
# 1       Q1
# 2       Q1
# 3       Q1
# 4       Q1
#
# [5 rows x 25 columns]

# %%
nba_shot_data.to_csv('NBA_shot_data2.csv')
